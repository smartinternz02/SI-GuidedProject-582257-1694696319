# %%
#loading and reading the file(TASK 1)
import pandas as pd
data=pd.read_csv('/content/House Price India.csv')
df=pd.DataFrame(data)
df.head(100)
# Out:
#             id   Date  number of bedrooms  number of bathrooms  living area  \
# 0   6762810145  42491                   5                 2.50         3650
# 1   6762810635  42491                   4                 2.50         2920
# 2   6762810998  42491                   5                 2.75         2910
# 3   6762812605  42491                   4                 2.50         3310
# 4   6762812919  42491                   3                 2.00         2710
# ..         ...    ...                 ...                  ...          ...
# 95  6762813766  42494                   4                 1.75         2010
# 96  6762813838  42494                   4                 2.50         3180
# 97  6762814206  42494                   4                 2.50         2450
# 98  6762814291  42494                   3                 2.50         2490
# 99  6762814896  42494                   3                 2.50         1680
#
# ...

# %%
#data visualization univariate
import matplotlib.pyplot as plt
plt.plot(df['living area'][1:40])#univariate taking living area as the feature of 39 values from row 1 to 39
plt.show()
plt.boxplot(df['Built Year'])
plt.show()
plt.pie(df['Built Year'][1:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c1d049a8280>,
# ...
#  [Text(1.0362730375727365, 0.36896909301427155, ''),
#   Text(0.5648392608774442, 0.943904978994932, ''),
#   Text(-0.18255291333845555, 1.084746253200094, ''),
#   Text(-0.8414088174363202, 0.7085416021239779, ''),
#   Text(-1.0999880629661385, 0.005124581153863535, ''),
#   Text(-0.8382264393871075, -0.7123036124521706, ''),
#   Text(-0.17788640344478485, -1.0855212699295576, ''),
#   Text(0.5583992954133888, -0.947728983877686, ''),
#   Text(1.0355437931401192, -0.3710108522522947, '')])

# %%
plt.plot(df['living area'][0:40],df['Price'][0:40])#bivariate plot living area vs pice.
plt.show()
plt.scatter(df['living area'][0:40],df['Price'][0:40])#bivariate scatterplot living area vs pice.
plt.show()
plt.bar(df['living area'][0:40],df['lot area'][0:40])#bivariate bargraph
# Out:
# <BarContainer object of 40 artists>

# %%
from matplotlib import rcParams
import seaborn as sns
sns.distplot(df['living area'])#univariate analysis of living area using distplot
plt.show()
# Out:
# <ipython-input-7-6b604be815ac>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['living area'])#univariate analysis of living area using distplot

# %%
sns.jointplot(x=df['living area'], y=df['Price'])#Bivariate analysis

# %%
sns.pairplot(df[['living area','Price','Date']])#multivariate analysis for the features living area, price , date

# %%
df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.029216           -0.322469
# Date                                   0.029216  1.000000           -0.018984
# number of bedrooms                    -0.322469 -0.018984            1.000000
# number of bathrooms                   -0.520038 -0.014500            0.504323
# living area                           -0.647009 -0.017154            0.558733
# lot area                              -0.094371 -0.000026            0.033185
# number of floors                      -0.312025 -0.004289            0.170669
# waterfront present                    -0.108522  0.005890           -0.005546
# number of views                       -0.294984  0.001238            0.090182
# condition of the house                -0.053088 -0.009898            0.028998
# grade of the house                    -0.677499 -0.026510            0.347356
# ...

# %%
sns.heatmap(df.corr())#multivariate analysis by heat map using corr of 23 column of df
# Out:
# <Axes: >

# %%
df.describe()#discriptive stats
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.005200e+04  10052.000000        10052.000000         10052.000000
# mean   6.762821e+09  42567.248806            3.386092             2.142211
# std    6.212973e+03     43.226800            0.945146             0.768713
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42531.000000            3.000000             1.750000
# 50%    6.762821e+09  42566.000000            3.000000             2.250000
# 75%    6.762826e+09  42603.000000            4.000000             2.500000
# max    6.762832e+09  42645.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  10052.000000  1.005200e+04      10052.000000        10052.000000
# mean    2109.767111  1.495464e+04          1.506168            0.007063
# std      928.249491  3.757007e+04          0.540345            0.083750
# ...

# %%
#no null values in the dataset so no need to handle them if there would have been any we could have replaced it by median
